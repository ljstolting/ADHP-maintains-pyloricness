# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
traj = np.loadtxt('./3D3/biastrack.dat').reshape(-1,3)

# %%
ax = plt.subplot(projection='3d')
backup = 174500
ax.plot3D(traj[-backup:,0],traj[-backup:,1],traj[-backup:,2])
